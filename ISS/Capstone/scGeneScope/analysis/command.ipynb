# %%
import numpy as np

# %%
treats = np.load("Treatments.npy", allow_pickle=True)
keys = ["phenacetin", "pq401", "splitomicin", "r_mg132", "r_roscovitine", "wy_14643", "fluocinonide", "caffeine", "ly303511", "simvastatin", "colchicine", "pantoprazole", "cycloheximide", "benzbromarone", "thapsigargin", "bay_11", "cgk_733", "pd_98059", "gw_843682x", "pma", "skii", "amg_900", "dbeq", "daporinad", "vorinostat", "quinidine", "aloxistatin", "harman"]
np.save("Treat_keys.npy", keys, allow_pickle=True)

# %%
lines = []
for i in range(28):
    treat = treats[i]
    key   = keys[i]
    lines.append(
        f"train experiment=imaging/singleprofile/train_on_concat_imagenet_vit_l "
        f"data.data_iter_factory.train.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.data_iter_factory.val.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.data_iter_factory.test.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.transform.condition.encode.path_to_categories.resource={key} "
        f"model.classifier.output_dim=2 NUM_CLASSES=2"
    )

with open("run_vs_dmso_cmds.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(lines) + "\n")

print("saved -> run_vs_dmso_cmds.txt")
# Out:
# saved -> run_vs_dmso_cmds.txt

# %%
lines2 = []
for i in range(28):
    treat = treats[i]
    key   = keys[i]
    lines2.append(
        f"train experiment=rnaseq/wilcoxon/wilcoxon_top1 "
        f"data.data_iter_factory.train.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.data_iter_factory.val.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.data_iter_factory.test.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.transform.condition.encode.path_to_categories.resource={key} "
        f"model.classifier.output_dim=2 NUM_CLASSES=2"
    )

with open("vsDMSO_GE_wilcoxon_top1.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(lines2) + "\n")

print("saved -> vsDMSO_GE_wilcoxon_top1.txt")
# Out:
# saved -> vsDMSO_GE_wilcoxon_top1.txt

# %%
lines3 = []
for i in range(28):
    treat = treats[i]
    key   = keys[i]
    lines3.append(
        f"train experiment=multimodal/singleprofile/altoslab/train_on_scvi_n200_with_concat_imagenet_vit_l "
        f"data.data_iter_factory.test.factory.rnaseq.samples_factory.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.data_iter_factory.train.factory.rnaseq.samples_factory.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.data_iter_factory.val.factory.rnaseq.samples_factory.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.data_iter_factory.test.factory.imaging.samples_factory.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.data_iter_factory.train.factory.imaging.samples_factory.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.data_iter_factory.val.factory.imaging.samples_factory.file_path.treatment_select='[\"{treat}\",\"DMSO\"]' "
        f"data.transform.example_transform.condition.encode.path_to_categories.resource={key} "
        f"model.classifier.output_dim=2 NUM_CLASSES=2 NUM_WORKERS=32"
    )

with open("vsDMSO_scVI_n200.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(lines3) + "\n")

print("saved -> vsDMSO_scVI_n200.txt")
# Out:
# saved -> vsDMSO_scVI_n200.txt
